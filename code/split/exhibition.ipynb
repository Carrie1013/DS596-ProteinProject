# %%
# %cd ../
import pandas as pd
from stability import Stability
from main import Split
# Out:
# /Users/qiaochufeng/Documents/GitHub/DS596-Project/code

# %%
stability_model = Stability()
stability_model.load_data()
stability_model.prepare_features()
stability_model.train()
stability_model.evaluate()
# Out:
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.8190 - mean_squared_error: 0.8190
# Test Loss (MSE): 0.8279594779014587, Test MSE: 0.8279594779014587
# (0.8279594779014587, 0.8279594779014587)

# %%
split_processor = Split(filepath="../data/processed/unsampled.csv")
split_processor.process()
accuracy, report = split_processor.train_mlp()
print(f"Accuracy: {accuracy}\n")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.979064039408867
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       795
#            1       0.00      0.00      0.00        17
#
#     accuracy                           0.98       812
#    macro avg       0.49      0.50      0.49       812
# weighted avg       0.96      0.98      0.97       812
# /opt/homebrew/Caskroom/miniforge/base/envs/cq1/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/homebrew/Caskroom/miniforge/base/envs/cq1/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/homebrew/Caskroom/miniforge/base/envs/cq1/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
split_processor = Split(filepath="../data/processed/over_sampled.csv")
split_processor.process()
accuracy, report = split_processor.train_mlp()
print(f"Accuracy: {accuracy}\n")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.922069825436409
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91       794
#            1       0.87      1.00      0.93       810
#
#     accuracy                           0.92      1604
#    macro avg       0.93      0.92      0.92      1604
# weighted avg       0.93      0.92      0.92      1604

# %%
split_processor = Split(filepath="../data/processed/under_sampled.csv")
split_processor.process()
accuracy, report = split_processor.train_mlp()
print(f"Accuracy: {accuracy}\n")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.7619047619047619
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74        11
#            1       0.69      0.90      0.78        10
#
#     accuracy                           0.76        21
#    macro avg       0.78      0.77      0.76        21
# weighted avg       0.79      0.76      0.76        21
# /opt/homebrew/Caskroom/miniforge/base/envs/cq1/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
split_processor = Split(filepath="../data/processed/unsampled_s.csv")
split_processor.process()
accuracy, report = split_processor.train_mlp()
print(f"Accuracy: {accuracy}\n")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.9728353140916808
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99       573
#            1       0.00      0.00      0.00        16
#
#     accuracy                           0.97       589
#    macro avg       0.49      0.50      0.49       589
# weighted avg       0.95      0.97      0.96       589
# /opt/homebrew/Caskroom/miniforge/base/envs/cq1/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/homebrew/Caskroom/miniforge/base/envs/cq1/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/homebrew/Caskroom/miniforge/base/envs/cq1/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
split_processor = Split(filepath="../data/processed/over_sampled_s.csv")
split_processor.process()
accuracy, report = split_processor.train_mlp()
print(f"Accuracy: {accuracy}\n")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.9554140127388535
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95       579
#            1       0.92      1.00      0.96       677
#
#     accuracy                           0.96      1256
#    macro avg       0.96      0.95      0.95      1256
# weighted avg       0.96      0.96      0.96      1256

# %%
split_processor = Split(filepath="../data/processed/under_sampled_s.csv")
split_processor.process()
accuracy, report = split_processor.train_mlp()
print(f"Accuracy: {accuracy}\n")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.7058823529411765
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.40      0.50      0.44         4
#            1       0.83      0.77      0.80        13
#
#     accuracy                           0.71        17
#    macro avg       0.62      0.63      0.62        17
# weighted avg       0.73      0.71      0.72        17
# /opt/homebrew/Caskroom/miniforge/base/envs/cq1/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
split_processor = Split(filepath="../data/processed/under_sampled_s.csv")
split_processor.process()
accuracy, report = split_processor.train_mlp()

df_test = split_processor.sampled_df.sample(n=20, random_state=42)  
x_test = df_test[['Site', 'Sequence', 'Secondary', 'Stability Sum']]
y_test = df_test[['Split']].astype(int).to_numpy().flatten()
y_test_pred = split_processor.eval(df_test)

from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(y_test, y_test_pred)
report = classification_report(y_test, y_test_pred)

print(f"Accuracy: {accuracy}\n")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.75
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62         6
#            1       0.85      0.79      0.81        14
#
#     accuracy                           0.75        20
#    macro avg       0.71      0.73      0.72        20
# weighted avg       0.76      0.75      0.75        20
# /opt/homebrew/Caskroom/miniforge/base/envs/cq1/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# %cd ../
import pandas as pd
from stability import Stability
from main import Split
# Out:
# /Users/qiaochufeng/Documents/GitHub/DS596-Project/code

# %%
import shap

split_processor = Split(filepath="../data/processed/under_sampled_s.csv")
split_processor.process()
accuracy, report = split_processor.train_mlp()

df_test = split_processor.sampled_df.sample(n=20, random_state=42)  
X_test_scaled, _ = split_processor.eval(df_test)
explainer = shap.KernelExplainer(split_processor.mlp_model.predict_proba, X_test_scaled)
shap_values = explainer.shap_values(X_test_scaled)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/envs/cq1/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
# Out:
# ---------------------------------------------------------------------------
# DimensionError                            Traceback (most recent call last)
# Cell In[13], line 6
#       4 # 选择一个样本，确保特征和 SHAP 值匹配
#       5 sample_index = 0
# ----> 6 shap.force_plot(
#       7     explainer.expected_value[1],  # 正类的基线值
#       8     shap_values_fixed[sample_index],  # 修正后的 SHAP 值
#       9     X_test_scaled[sample_index],     # 对应特征值
#      10     matplotlib=True
#      11 )
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/cq1/lib/python3.9/site-packages/shap/plots/_force.py:181, in force(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation, contribution_threshold)
#     176     if len(features) == shap_values.shape[1] - 1:
#     177         emsg += (
#     178             " You might be using an old format shap_values array with the base value "
#     179             "as the last column. In this case, just pass the array without the last column."
#     180         )
# --> 181     raise DimensionError(emsg)
#     183 instance = Instance(np.zeros((1, len(feature_names))), features)
#     184 e = AdditiveExplanation(
#     185     base_value,
#     186     np.sum(shap_values[0, :]) + base_value,
#    (...)
#     192     DenseData(np.zeros((1, len(feature_names))), list(feature_names))
#     193 )
#
# DimensionError: Length of features is not equal to the length of shap_values!

# %%
shap_values = explainer.shap_values(X_test_scaled)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
